# %%
import numpy as np
data = np.array([map(float, l.split()) for l in open('housing.data')])
y = data
print ('Data points', len(y))
print (y)
# Out:
# Data points 506
# [<map object at 0x7f2cf3135a20> <map object at 0x7f2cf3135da0>
#  <map object at 0x7f2cf31360f0> <map object at 0x7f2cf3136438>
#  <map object at 0x7f2cf3136780> <map object at 0x7f2cf3136ac8>
#  <map object at 0x7f2cf3136e48> <map object at 0x7f2cf3133198>
#  <map object at 0x7f2cf31334e0> <map object at 0x7f2cf3133828>
#  <map object at 0x7f2cf3133b38> <map object at 0x7f2cf3133eb8>
#  <map object at 0x7f2cf3138780> <map object at 0x7f2cf3138710>
#  <map object at 0x7f2cf3138a58> <map object at 0x7f2cf31389e8>
#  <map object at 0x7f2cf3138cf8> <map object at 0x7f2cf313a0b8>
#  <map object at 0x7f2cf313a2b0> <map object at 0x7f2cf313a8d0>
#  <map object at 0x7f2cf313ac18> <map object at 0x7f2cf313b1d0>
#  <map object at 0x7f2cf313b320> <map object at 0x7f2cf313b8d0>
#  <map object at 0x7f2cf313bba8> <map object at 0x7f2cf313be80>
#  <map object at 0x7f2cf313d198> <map object at 0x7f2cf313d470>
#  <map object at 0x7f2cf313d748> <map object at 0x7f2cf313dd68>
# ...
